# %%
import pandas as pd
from sas7bdat import SAS7BDAT

# %%
with SAS7BDAT("C:/Users/maserati/Documents/Mémoire M1 - Copie/Base de données/base de données SAS/Données/coeftest1.sas7bdat") as file:
    coef1 = file.to_data_frame()
coef1
# Out:
#   _LINK_ _TYPE_     _STATUS_        _NAME_  Intercept    CS_el2    CS_el3  \
# 0  LOGIT  PARMS  1 Avertisse  indice_vic_b -23.986472  0.085598  0.101822
#
#      CS_el4    CS_el5  CS_peur2  ...  VS_embrass4  VS_embrass5   V_vols2  \
# 0  0.255037 -0.487711   0.03221  ...    -0.191182    -0.581673 -0.007255
#
#     V_vols3   V_Vol12   V_Vol13  V_jeux22  V_jeux23    _LNLIKE_  _ESTTYPE_
# 0 -0.211117 -0.116792  0.688098 -0.162849 -0.048012 -956.578325        MLE
#
# [1 rows x 69 columns]

# %%
coef1 = coef1.drop(columns=['_LINK_','_TYPE_','_STATUS_','_NAME_','_LNLIKE_','_ESTTYPE_'])

# %%
lcoef1 = list(coef1.iloc[0])
lcoef1
# Out:
# [-23.986472349238547,
#  0.08559771971252478,
#  0.10182205872568957,
#  0.2550372718384483,
#  -0.4877105946136578,
#  0.03220995398923704,
#  -0.06626158993225598,
#  -0.05658243040765602,
#  -0.2184604707025671,
#  -0.24605578167666134,
#  9.421090812832384,
#  9.404359913561752,
#  0.1619630180484775,
#  -0.17389415542458575,
#  9.435100635472523,
#  9.649114745566479,
#  -0.2811587145366812,
#  -0.05498448709445669,
#  9.53677614639761,
#  9.567918844069348,
#  1.1811282051456629,
#  0.01650388928424818,
#  0.2500863014704405,
#  0.06687555846426965,
#  0.5032299827745423,
#  -0.0743779175706741,
#  9.56849665245057,
#  9.765616531632602,
#  -0.038198861801304516,
#  0.001905724484946799,
#  9.91235960374865,
#  10.281861326416816,
#  0.4618475854042039,
#  -0.1146457758814989,
#  9.77448564654828,
#  9.685110898657783,
#  -0.07524694907795142,
#  0.07151857138025428,
#  9.753871478353094,
#  10.103272622596855,
#  -0.09615373779010726,
#  -0.12059761037184123,
# ...

# %%
reponses = []
reponses.clear()
coef =[]
coef.clear()
def application():

    Q1 = "Q1-Comment t'entends-tu avec les autres élèves ?"
    O1 = ["très bien", "bien", "pas très bien", "pas bien du tout", "je ne sais pas"]
    print(Q1)
    for i, option in enumerate(O1, start=1):
        print(f"{i}. {option}")
    choix1 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix1)
    if choix1 == 1 :
        coef.append(0)
    elif choix1 == 2 :
        coef.append(lcoef1[1])
    elif choix1 == 3 :
        coef.append(lcoef1[2])
    elif choix1 == 4 :
        coef.append(lcoef1[3])
    elif choix1 == 5 :
        coef.append(lcoef1[4])

    Q2 = "Q2-Depuis le début de l'année scolaire, as-tu déjà eu peur de venir à l'école à cause de la violence ?"
    O2 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q2)
    for i, option in enumerate(O2, start=1):
        print(f"{i}. {option}")
    choix2 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix2)

    if choix2 == 1 :
        coef.append(0)
    elif choix2 == 2 :
        coef.append(lcoef1[5])
    elif choix2 == 3 :
        coef.append(lcoef1[6])
    elif choix2 == 4 :
        coef.append(lcoef1[7])
    elif choix2 == 5 :
        coef.append(lcoef1[8])

    Q3 = "Q3-Depuis le début de l’année scolaire, t’a-t-on donné un surnom méchant ?"
    O3 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q3)
    for i, option in enumerate(O3, start=1):
        print(f"{i}. {option}")
    choix3 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix3)
    if choix3 == 1 :
        coef.append(0)
    elif choix3 == 2 :
        coef.append(lcoef1[9])
    elif choix3 == 3 :
        coef.append(lcoef1[10])
    elif choix3 == 4 :
        coef.append(lcoef1[11])
    elif choix3 == 5 :
        coef.append(lcoef1[12])

    Q4 = "Q4-Depuis le début de l’année scolaire, s’est-on moqué de toi ou as-tu été insulté(e) dans ton école ou sur le chemin pour y venir ?"
    O4 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q4)
    for i, option in enumerate(O4, start=1):
        print(f"{i}. {option}")
    choix4 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix4)

    if choix4 == 1 :
        coef.append(0)
    elif choix4 == 2 :
        coef.append(lcoef1[13])
    elif choix4 == 3 :
        coef.append(lcoef1[14])
    elif choix4 == 4 :
        coef.append(lcoef1[15])
    elif choix4 == 5 :
        coef.append(lcoef1[16])

    Q5 = "Q5-Depuis le début de l’année scolaire, as-tu été mis ou mise à l'écart par des élèves ?"
    O5 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q5)
    for i, option in enumerate(O5, start=1):
        print(f"{i}. {option}")
    choix5 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix5)

    if choix5 == 1 :
        coef.append(0)
    elif choix5 == 2 :
        coef.append(lcoef1[17])
    elif choix5 == 3 :
        coef.append(lcoef1[18])
    elif choix5 == 4 :
        coef.append(lcoef1[19])
    elif choix5 == 5 :
        coef.append(lcoef1[20])

    Q6 = "Q6-Depuis le début de l’année scolaire, quelqu'un t'a-t-il déjà fait mal volontairement à l'école ou sur le chemin pour y venir ?"
    O6 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q6)
    for i, option in enumerate(O5, start=1):
        print(f"{i}. {option}")
    choix6 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix6)

    if choix6 == 1 :
        coef.append(0)
    elif choix6 == 2 :
        coef.append(lcoef1[21])
    elif choix6 == 3 :
        coef.append(lcoef1[22])
    elif choix6 == 4 :
        coef.append(lcoef1[23])
    elif choix6 == 5 :
        coef.append(lcoef1[24])

    Q7 = "Q7-Depuis le début de l'année scolaire, t'a-t-on bousculé(e) pour te faire mal dans ton école ou sur le chemin pour y venir ?"
    O7 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q7)
    for i, option in enumerate(O7, start=1):
        print(f"{i}. {option}")
    choix7 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix7)

    if choix7 == 1 :
        coef.append(0)
    elif choix7 == 2 :
        coef.append(lcoef1[25])
    elif choix7 == 3 :
        coef.append(lcoef1[26])
    elif choix7 == 4 :
        coef.append(lcoef1[27])
    elif choix7 == 5 :
        coef.append(lcoef1[28])

    Q8 = "Q8-Depuis le début de l'année scolaire, t'a-t'on lancé des objets pour te faire mal dans ton école ou sur le chemin pour y venir ?"
    O8 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q8)
    for i, option in enumerate(O8, start=1):
        print(f"{i}. {option}")
    choix8 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix8)

    if choix8 == 1 :
        coef.append(0)
    elif choix8 == 2 :
        coef.append(lcoef1[29])
    elif choix8 == 3 :
        coef.append(lcoef1[30])
    elif choix8 == 4 :
        coef.append(lcoef1[31])
    elif choix8 == 5 :
        coef.append(lcoef1[32])
        
    Q9 = "Q9-Depuis le début de l’année scolaire, as-tu été frappé(e) dans ton école ou sur le chemin pour y venir ?"
    O9 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q9)
    for i, option in enumerate(O9, start=1):
        print(f"{i}. {option}")
    choix9 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix9)

    if choix9 == 1 :
        coef.append(0)
    elif choix9 == 2 :
        coef.append(lcoef1[33])
    elif choix9 == 3 :
        coef.append(lcoef1[34])
    elif choix9 == 4 :
        coef.append(lcoef1[35])
    elif choix9 == 5 :
        coef.append(lcoef1[36])

    Q10 = "Q10-Depuis le début de l’année scolaire, as-tu déjà été menacé(e) dans ton école ou sur le chemin pour y venir ?"
    O10 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q10)
    for i, option in enumerate(O10, start=1):
        print(f"{i}. {option}")
    choix10 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix10)

    if choix10 == 1 :
        coef.append(0)
    elif choix10 == 2 :
        coef.append(lcoef1[37])
    elif choix10 == 3 :
        coef.append(lcoef1[38])
    elif choix10 == 4 :
        coef.append(lcoef1[39])
    elif choix10 == 5 :
        coef.append(lcoef1[40])

    Q11 = "Q11-Depuis le début de l’année scolaire, t'es-tu déjà bagarré(e) dans l'école ou sur le chemin pour y venir ?"
    O11 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q11)
    for i, option in enumerate(O11, start=1):
        print(f"{i}. {option}")
    choix11 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix11)
    if choix11 == 1 :
        coef.append(0)
    elif choix11 == 2 :
        coef.append(lcoef1[41])
    elif choix11 == 3 :
        coef.append(lcoef1[42])
    elif choix11 == 4 :
        coef.append(lcoef1[43])
    elif choix11 == 5 :
        coef.append(lcoef1[44])
    
    Q12 = "Q12-Depuis le début de l’année scolaire, est-il arrivé que tu aies peur dans les toilettes de ton école ?"
    O12 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q12)
    for i, option in enumerate(O12, start=1):
        print(f"{i}. {option}")
    choix12 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix12)

    if choix12 == 1 :
        coef.append(0)
    elif choix12 == 2 :
        coef.append(lcoef1[45])
    elif choix12 == 3 :
        coef.append(lcoef1[46])
    elif choix12 == 4 :
        coef.append(lcoef1[47])
    elif choix12 == 5 :
        coef.append(lcoef1[48])

    Q13 = "Q13-Depuis le début de l’année scolaire, as-tu été gêné(e) par quelqu’un qui te regardait quand tu étais aux toilettes ?"
    O13 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q13)
    for i, option in enumerate(O13, start=1):
        print(f"{i}. {option}")
    choix13 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix13)

    if choix13 == 1 :
        coef.append(0)
    elif choix13 == 2 :
        coef.append(lcoef1[49])
    elif choix13 == 3 :
        coef.append(lcoef1[50])
    elif choix13 == 4 :
        coef.append(lcoef1[51])
    elif choix13 == 5 :
        coef.append(lcoef1[52])

    Q14 = "Q14-Depuis le début de l’année scolaire, dans ton école, est-ce qu'un ou une élève a essayé de t'embrasser sans que tu sois d'accord ?"
    O14 = [ "non, jamais", "oui, quelquefois", "oui, souvent","oui, très souvent", "je ne sais pas"]
    print(Q14)
    for i, option in enumerate(O14, start=1):
        print(f"{i}. {option}")
    choix14 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix14)

    if choix14 == 1 :
        coef.append(0)
    elif choix14 == 2 :
        coef.append(lcoef1[53])
    elif choix14 == 3 :
        coef.append(lcoef1[54])
    elif choix14 == 4 :
        coef.append(lcoef1[55])
    elif choix14 == 5 :
        coef.append(lcoef1[56])
    
    Q15 = "Q15-Depuis le début de l’année scolaire, t’a-t-on volé(e) quelque chose à l'école ?"
    O15 = [ "non, jamais", "oui", "je ne sais pas"]
    print(Q15)
    for i, option in enumerate(O15, start=1):
        print(f"{i}. {option}")
    choix15 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix15)

    if choix15 == 1 :
        coef.append(0)
    elif choix15 == 2 :
        coef.append(lcoef1[57])
    elif choix15 == 3 :
        coef.append(lcoef1[58])

    Q16 = "Q16-Depuis le début de l'année scolaire, t'a-t-on menacé(e) pour te voler quelque chose dans ton école ou sur le chemin pour y venir ?"
    O16 = [ "non, jamais", "oui", "je ne sais pas"]
    print(Q16)
    for i, option in enumerate(O16, start=1):
        print(f"{i}. {option}")
    choix16 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix16)

    if choix16 == 1 :
        coef.append(0)
    elif choix16 == 2 :
        coef.append(lcoef1[59])
    elif choix16 == 3 :
        coef.append(lcoef1[60])

    Q17 = "Q17-Depuis le début de l’année scolaire, as-tu participé à un jeu, une activité qui te semble dangereux, qui peut faire mal ou qui peut blesser ?"
    O17 = [ "non, je n'ai jamais participé à un jeu dangereux", "oui, j’ai participé à un jeu dangereux", "je ne sais pas"]
    print(Q17)
    for i, option in enumerate(O17, start=1):
        print(f"{i}. {option}")
    choix17 = int(input("Choisissez un numéro correspondant à votre réponse : "))
    reponses.append(choix17)

    if choix17 == 1 :
        coef.append(0)
    elif choix17 == 2 :
        coef.append(lcoef1[61])
    elif choix17 == 3 :
        coef.append(lcoef1[62])
    
    return reponses

# %%
application()
score = sum(coef) + lcoef1[0]
print(f'Votre score est de : {round(score,2)}')
# Out:
# Q1-Comment t'entends-tu avec les autres élèves ?
# 1. très bien
# 2. bien
# 3. pas très bien
# 4. pas bien du tout
# 5. je ne sais pas
